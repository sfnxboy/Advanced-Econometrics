# %% [markdown]
# # Problem Set 4
# ## Amir ElTabakh
# ## Due: 3/11/2022 - 11:59PM
#
# 1.
#
# In univariate time-series modeling, one class of models is known as autoregressive (AR)
# models. For example, an AR(2) process can be written as
#
# $y_t = \alpha_1 y_{t-1} + \alpha_2 y_{t-2} + u_t$
#
# for $t = 1, 2, . . . , T$. The subscript $t$ denotes time periods and $T$ is the last period. Now, suppose $\alpha_1 = 0.8$, $\alpha_2 = 0.15$ and $u_t$’s are independently and identically distributed standard normal random variables. Consider the code snippet below that simulates the AR(2) for 200 periods and keeps the last 100 periods.

# %%
import numpy as np
np.random.seed(37)
import matplotlib.pyplot as plt
plt.style.use('ggplot')

T = 200
alpha1 = 0.8
alpha2 = 0.15
u = np.random.randn(T)
y = np.zeros(T)
for t in range(2, T):
    y[t] = alpha1*y[t-1] + alpha2*y[t-2] + u[t]

y = y[100:] # keep the last 100 periods

# %% [markdown]
# Why do you think the for loop started from index 2?
#
# Answer: You need elements at index 0 and 1 in the function.
#
# Write a while loop which generates 100 observations from the AR(2) process defined above, and then generates a line plot of the simulated AR(2) process as in Figure 1.

# %%
# importing dependecies
import seaborn as sns
sns.set(rc={"figure.figsize":(10, 6)}) #width=10, #height=6

# x-axis
periods = np.arange(2, 102)

# generating plot
sns.lineplot(x = periods, y = y, color = "blue")

# %% [markdown]
# 2. Consider the following code snippet. Write a control structure that adds odd numbers in x to the empty list odd, and even numbers in x to the empty list even.

# %%
import decimal

x = np.arange(15)
odd = [] # empty list for odd numbers
even = [] # empty list for even numbers


for i in x:
    if i % 2 == 0:
        even += [i]
    else:
        odd += [i]
        
print(f"Even: {even}")
print(f"Odd: {odd}")
# Out:
# Even: [0, 2, 4, 6, 8, 10, 12, 14]
# Odd: [1, 3, 5, 7, 9, 11, 13]

# %% [markdown]
# 3. Consider the following code snippet. The object letters is a set containing lower case letters. Write a control structure that adds vowels to the set vowel, and consonants to the set consonant. Note that the vowels are {a,e,i,o,u}, and the rest of the letters are consonants.

# %%
from string import ascii_lowercase
letters = set(ascii_lowercase)
vowel = set()
consonant = set()
all_vowels = ['a', 'e', 'i', 'o', 'u']


for letter in letters:
    if letter in all_vowels:
        vowel.add(letter)
    else:
        consonant.add(letter)

print(vowel)
print(consonant)
# Out:
# {'e', 'o', 'a', 'i', 'u'}
# {'j', 'g', 'b', 'y', 's', 'm', 'c', 'q', 't', 'n', 'l', 'p', 'z', 'w', 'r', 'h', 'x', 'f', 'k', 'd', 'v'}

# %% [markdown]
# 4. Take a look at Figure 2 above. Complete the code snippet below to generate Figure 2.

# %%
x = np.linspace(0, 10, 100)
sinx = np.sin(x)
cosx = np.cos(x)

# importing dependecies
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.plot(x, sinx, label='sin(x)', color = 'red')
plt.plot(x, cosx, label='cos(x)', color = 'blue', linestyle='dashed')
plt.xlabel('x')
plt.ylabel('sin(x)/cos(x)')
plt.title("Sine and Cosine Functions")
plt.legend(loc = 3)

# %% [markdown]
# 5. Modify your code snippet for question 4 to generate Figure 3 below. Note that the markers in the plot have following properties: `markeredgecolor = "black"`, `markersize = 5`.

# %%
x = np.arange(0, 10, 0.1)
sinx = np.sin(x)
cosx = np.cos(x)

# importing dependecies
import matplotlib.pyplot as plt
import matplotlib.path as mpath

# generating ellipse
circle = mpath.Path.unit_circle()
verts = np.copy(circle.vertices)
verts[:, 0] *= 1.3
ellipt_marker = mpath.Path(verts, circle.codes)

plt.figure(figsize=(10, 6))
plt.plot(x, sinx, label='sin(x)', color = 'green', marker = ellipt_marker,
         ms = 7, linestyle = 'None', markeredgecolor = "black")
plt.plot(x, cosx, label='cos(x)', color = 'red', marker = "D",
         ms = 5, linestyle = 'None', markeredgecolor = "black")
plt.xlabel('x')
plt.ylabel('sin(x)/cos(x)')
plt.title("Sine and Cosine Functions")
plt.legend(loc = 3)

# %% [markdown]
# 6. The web page http://pypl.github.io/PYPL.html provides an index showing how often programming languages are searched on Google. Consider the first 15 programming languages in the index. Write a Python program that displays a bar chart of the popularity of these 15 languages (just copy and paste names and associated values to your script file). Your bar chart should display the share of each programming language. Your code snippet should resemble Figure 4 above. Note that plotting command `plt.barh` is used to generate horizontal bar charts.

# %%
# In case you don't have beautifulsoup4 installed
#!pip install beautifulsoup4

# %%
# import dependencies
from bs4 import BeautifulSoup
import pandas as pd

# Its nearly impossible to scrape a Github.io site. I had to copy over the table.
table_1 = """
<div id="table"><table class="table"><tbody><tr><th class="center">Rank<br></th><th class="center">Change</th><th>Language</th><th class="center">Share</th><th class="optCol center">Trend</th></tr><tr><!-- begin section All--><td class="center">1</td><td class="center"></td><td>Python</td><td class="right">28.27 %</td><td class="right optCol">-2.0 %</td></tr><tr><td class="center">2</td><td class="center"></td><td>Java</td><td class="right">18.03 %</td><td class="right optCol">+0.8 %</td></tr><tr><td class="center">3</td><td class="center"></td><td>JavaScript</td><td class="right">8.86 %</td><td class="right optCol">+0.4 %</td></tr><tr><td class="center">4</td><td class="center"></td><td>C#</td><td class="right">7.51 %</td><td class="right optCol">+0.6 %</td></tr><tr><td class="center">5</td><td class="center"></td><td>C/C++</td><td class="right">7.32 %</td><td class="right optCol">+0.6 %</td></tr><tr><td class="center">6</td><td class="center"></td><td>PHP</td><td class="right">5.71 %</td><td class="right optCol">-0.4 %</td></tr><tr><td class="center">7</td><td class="center"></td><td>R</td><td class="right">4.23 %</td><td class="right optCol">+0.5 %</td></tr><tr><td class="center">8</td><td class="center"></td><td>Objective-C</td><td class="right">2.28 %</td><td class="right optCol">-1.2 %</td></tr><tr><td class="center">9</td><td class="center"><img src="Up.png"></td><td>TypeScript</td><td class="right">2.11 %</td><td class="right optCol">+0.3 %</td></tr><tr><td class="center">10</td><td class="center"><img src="Down.png"></td><td>Swift</td><td class="right">2.01 %</td><td class="right optCol">+0.2 %</td></tr><tr><td class="center">11</td><td class="center"></td><td>Matlab</td><td class="right">1.87 %</td><td class="right optCol">+0.2 %</td></tr><tr><td class="center">12</td><td class="center"></td><td>Kotlin</td><td class="right">1.57 %</td><td class="right optCol">-0.1 %</td></tr><tr><td class="center">13</td><td class="center"></td><td>Go</td><td class="right">1.19 %</td><td class="right optCol">-0.1 %</td></tr><tr><td class="center">14</td><td class="center"><img src="Up.png"><img src="Up.png"></td><td>Rust</td><td class="right">1.14 %</td><td class="right optCol">+0.2 %</td></tr><tr><td class="center">15</td><td class="center"></td><td>Ruby</td><td class="right">1.12 %</td><td class="right optCol">-0.0 %</td></tr><tr><td class="center">16</td><td class="center"><img src="Down.png"><img src="Down.png"></td><td>VBA</td><td class="right">1.1 %</td><td class="right optCol">-0.1 %</td></tr><tr><td class="center">17</td><td class="center"></td><td>Ada</td><td class="right">0.79 %</td><td class="right optCol">+0.1 %</td></tr><tr><td class="center">18</td><td class="center"><img src="Up.png"><img src="Up.png"><img src="Up.png"><img src="Up.png"></td><td>Abap</td><td class="right">0.68 %</td><td class="right optCol">+0.2 %</td></tr><tr><td class="center">19</td><td class="center"><img src="Up.png"><img src="Up.png"></td><td>Dart</td><td class="right">0.67 %</td><td class="right optCol">+0.1 %</td></tr><tr><td class="center">20</td><td class="center"><img src="Down.png"><img src="Down.png"></td><td>Visual Basic</td><td class="right">0.64 %</td><td class="right optCol">-0.0 %</td></tr><tr><td class="center">21</td><td class="center"><img src="Down.png"><img src="Down.png"></td><td>Scala</td><td class="right">0.61 %</td><td class="right optCol">+0.0 %</td></tr><tr><td class="center">22</td><td class="center"><img src="Down.png"><img src="Down.png"></td><td>Lua</td><td class="right">0.47 %</td><td class="right optCol">-0.1 %</td></tr><tr><td class="center">23</td><td class="center"></td><td>Perl</td><td class="right">0.46 %</td><td class="right optCol">-0.0 %</td></tr><tr><td class="center">24</td><td class="center"></td><td>Groovy</td><td class="right">0.45 %</td><td class="right optCol">+0.1 %</td></tr><tr><td class="center">25</td><td class="center"></td><td>Julia</td><td class="right">0.34 %</td><td class="right optCol">-0.0 %</td></tr><tr><td class="center">26</td><td class="center"><img src="Up.png"></td><td>Haskell</td><td class="right">0.32 %</td><td class="right optCol">+0.1 %</td></tr><tr><td class="center">27</td><td class="center"><img src="Down.png"></td><td>Cobol</td><td class="right">0.24 %</td><td class="right optCol">-0.1 %</td><!-- end section All--></tr><tr><td colspan="5" align="right">© Pierre Carbonnelle, 2022</td></tr></tbody></table></div>
"""
soup = BeautifulSoup(table_1, 'html.parser')

table_data = soup.find_all('td')
data = [j.text for j in table_data][:-1]
#print(data)

df = pd.DataFrame(columns = ["Rank", "Change", "Language", "Share", "Trend"])

for i in range(0, len(data), 5):
  row = pd.DataFrame({"Rank" : data[i],
                      "Change" : data[i + 1],
                      "Language" : data[i + 2],
                      "Share" : data[i + 3],
                      "Trend" : data[i + 4]
                      }, index=[0])
  df = df.append(row, ignore_index = True)

# Delete `Change` column
del df['Change']

# Remove " %" from `Share` column
df['Share'] = df['Share'].str[:-2].astype(float)

# output df
df
# Out:
#    Rank      Language  Share   Trend
# 0     1        Python  28.27  -2.0 %
# 1     2          Java  18.03  +0.8 %
# 2     3    JavaScript   8.86  +0.4 %
# 3     4            C#   7.51  +0.6 %
# 4     5         C/C++   7.32  +0.6 %
# 5     6           PHP   5.71  -0.4 %
# 6     7             R   4.23  +0.5 %
# 7     8   Objective-C   2.28  -1.2 %
# 8     9    TypeScript   2.11  +0.3 %
# 9    10         Swift   2.01  +0.2 %
# 10   11        Matlab   1.87  +0.2 %
# 11   12        Kotlin   1.57  -0.1 %
# 12   13            Go   1.19  -0.1 %
# 13   14          Rust   1.14  +0.2 %
# 14   15          Ruby   1.12  -0.0 %
# 15   16           VBA   1.10  -0.1 %
# 16   17           Ada   0.79  +0.1 %
# 17   18          Abap   0.68  +0.2 %
# 18   19          Dart   0.67  +0.1 %
# 19   20  Visual Basic   0.64  -0.0 %
# 20   21         Scala   0.61  +0.0 %
# 21   22           Lua   0.47  -0.1 %
# 22   23          Perl   0.46  -0.0 %
# 23   24        Groovy   0.45  +0.1 %
# ...

# %%
# Generating bar plot
sns.barplot(x="Share", y="Language", data=df,
            label="Total", color="magenta")

# %% [markdown]
# 7.  Consider again the index mentioned in question 6. Write a Python program that
# instead displays a pie chart of the popularity of these programming languages. Your
# code snippet should resemble Figure 5 below.

# %%
import matplotlib.pyplot as plt

#define Seaborn color palette to use
colors = sns.color_palette('pastel')[0:len(df)]

# explode
explode = np.append(np.repeat(0.1, 6), np.append(np.array(0.6), np.append(np.repeat(1, 6), np.append(np.repeat(1.5, len(df) - 18), np.repeat(2.5, 5)))))

#create pie chart
plt.pie(x = df['Share'], labels = df['Language'], colors = colors, autopct='%1.1f%%', explode = explode)
plt.show()

# %% [markdown]
# There is a reason why Pie Charts are looked down upon.
